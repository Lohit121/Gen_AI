# %%
##Datastructues in python are being used to store data in a structured way. It is a collection of data which can be of different types.
#  It is used to store and manipulate data in a efficient way. There are different types of data structures in python such as list, tuple, set, 
# dictionary etc. Each data structure has its own characteristics and use cases. In this notebook we will learn about the basic data structures 
# in python and how to use them.
# 1. List: A list is a collection of items which are ordered and changeable. It is defined by using square brackets [] and items are separated by commas.
# 2. Tuple: A tuple is a collection of items which are ordered and unchangeable. It is defined by using parentheses () and items are separated by commas.
# 3. Set: A set is a collection of items which are unordered and unchangeable. It is defined by using curly braces {} and items are separated by commas.
# 4. Dictionary: A dictionary is a collection of items which are unordered, changeable and indexed. It is defined by using curly braces {} and items are separated by commas. Each item is a key-value pair.
