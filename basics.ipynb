# %%
'''1
a=1
name = "lohit"
a=7.990848349
print("name is ",name)
_name1= "_sochit"
print(_name1)
1_name1 = "_sochit"
print(1_name1)
cant do this because variables cant start with numbers

print("_name1 type is ",type(_name1))

# integer can be converted to string not vice versa '''
#from operator import truediv
#from threading import main_thread

'''name3='lohit'
#name4=int(name3)
name3=33
name4=str(name3)
print(name4)
Input function only takes the input in string format until and unlesss  we explicitly take the input in integer or other format 
age = int (input ('enter age '))
#print(type(age))'''
'''

age = bool(input("enter ur age "))
print(type(age))
print(age)

#BUILDING A simple  CALUCULATOR
value_1=(int(input("enter your first number")))
value_2=(int(input("enter your second number")))
print("The addition for the values is :", value_1 + value_2)
print("The substraction for the values is :", value_1 - value_2)
print("The product for the values is :", value_1 * value_2)
print("The division for the values is :", value_1 / value_2)
1'''

#1'''
##Data types are classsification of data that tells the compiler or the interpreter that what kind of values we cn store into a variable
#and how much memory will be  comsumed to store the data and the operations it  can perform
'''age = input("enter the age")
print(type(age))
age2=(int(input("enter your second age" )))
print(type(age2))
#always create number variable with type int as variable defaluts to string  and we can perform arthematic operations on the defalut variables if we want to in future code vv
#different types of data types
#1.int
#2 str
#3 bool
#4 float
a=23
b="Amit"
type(b)
c=True
print(type(c))
a=7
b=7+1
print(a==b)'''

''''#operators
#operators helps in applying operations on the given operands
1.arthematic operators
addition (+)
substraction(-)
product(*)
division(/)
Modulus(%)
floor(//)
exponent(a**b)

2.comparison operators
Greater than (>)
less than (<)
Greater than or equal to (>=)
less than or equal to (<=)
Equality chek(==)
not equal to (!=)
3 Logical operators 
and --- whether if both conditions are true or not 
or --- whether if any of the operation is true or not 
not --- negation or to inverse the result of givem operation   

a=5
b=6
print(a+b)

a=18
b=5
c=a/b
c=a%b
c=a-b
c=a//b #removes decimal after division
c=a**b #18 power 5 , exponential  operator
#print(a==b)
c=a>b
print(c)

#Logical Operators
a=10
b=6
c=7
print(not(a>b and b>c or c>a))
'''
#Simple Caluculator
a=int(input("enter first number"))
b=int(input("enter second number"))
operation = input("Enter the operation out of +,-,*,/")

if operation == "+":
    print(a+b)
if operation == "-":
    print(a-b)
if operation == "*":
    print(a*b)
if operation == "/":
    print(a/b)
# Out:
# 23
