# %% [markdown]
# # List

# %% [markdown]
# ## List are one of the type of data structure which sre used for storing your data in a structured format where you can store data of any data type and that as it is one of the data structure so we can have access to the data as well that we are going to store into the list and we can apply crud operations as well i.e create , read update , delete operations as well

# %%
a=list()

# %%
type(a)
# Out:
# list

# %%
lists = ["lohit",2,2.3,True]
lists
# Out:
# ['lohit', 2, 2.3, True]

# %%
#we can apply crud operations as well i.e create , read update , delete operations as well
lists = ["lohit",2,2.3,True,99999]

# %%
lists
# Out:
# ['lohit', 2, 2.3, True, 99999]

# %%
lists
# Out:
# ['lohit', 2, 2.3, True, 99999]

# %% [markdown]
# ## Lists are ordered and mutable Data structure

# %% [markdown]
# ## List Indexing

# %%
## By using the proper indexing value we can retrieve the data from our lists 

lists[0]
# Out:
# 'lohit'

# %%
len(lists)
# Out:
# 5

# %%
##length of data structure is going to be the number of elements(items) present in that data structure 
print(lists[4])
# Out:
# 99999

# %%
lists=["apple","banana","grapes","orange","pineapple","watermelon"]
lists[5]
# Out:
# 'watermelon'

# %%
lists[2]
# Out:
# 'grapes'

# %%
#Negative indexing ---> In any data structure we can access data using negative indexing as well
lists[-1]
# Out:
# 'watermelon'

# %%
 print(lists[-2])
# Out:
# pineapple

# %%
# For having access to all the values you are going to store the list , you can use 
lists[:]
# Out:
# ['apple', 'banana', 'grapes', 'orange', 'pineapple', 'watermelon']

# %% [markdown]
# ## List Slicing

# %% [markdown]
# ## List slicing can help us out with retrieving a specific data points from our list

# %%
lists[2:4]
# Out:
# ['grapes', 'orange']

# %%
#to print in reverse order 
lists[::-1]
# Out:
# ['watermelon', 'pineapple', 'orange', 'grapes', 'banana', 'apple']

# %% [markdown]
# ## Lists are Mutabe

# %% [markdown]
# ##### By mentioning that Lists are mutable we mean to say that we can replace the values present at a specific location inside our list

# %%
lists[2] = "hazelnut"

# %%
lists
# Out:
# ['apple', 'banana', 'hazelnut', 'orange', 'pineapple', 'watermelon']

# %% [markdown]
# ### By using Looping statements we can iterate through list as well

# %%
for item in lists:
    print(item)
# Out:
# apple
# banana
# hazelnut
# orange
# pineapple
# watermelon

# %%
list_item = [1,3,4,"lohit",True,2.3]

# %%
for item in list_item:
    print(item)
# Out:
# 1
# 3
# 4
# lohit,
# True
# 2.3

# %%
list_item[3:]
# Out:
# ['lohit,', True, 2.3]

# %%
list_item[::-2]
# Out:
# [2.3, 'lohit,', 3]
