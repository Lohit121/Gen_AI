# %% [markdown]
# ## Keywords

# %% [markdown]
# #### keywords are the assigned words which cant be used as our variable name as they are having a reserved meaning already in python

# %%
list = "lohit" 
list
# Out:
# 'lohit'

# %%
tuple = (1,2,3,4,5)
tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
set
# Out:
# set

# %%
# Out:
# ['lohit', 2, 2.3, True]
